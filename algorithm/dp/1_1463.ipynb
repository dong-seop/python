# %%
import matplotlib.pyplot as plt

# %%
# y = 2x +1  x = {1:20}

x1 = [i for i in range(1,21,2)]
x2 = list(range(1,21))

y = [-2*i+1 for i in x]

# %%
plt.plot(x,y)
plt.grid(True)
plt.show()

# %%
import numpy as np
x =np.arange(-1,1,0.05)

y = np.sqrt(1-x*x)

# %%
a = np.random.rand(3,3)
print(a)
np.diag(a)
# Out:
# [[0.86152769 0.84051491 0.50327632]
#  [0.28794369 0.86681813 0.31136161]
#  [0.88705174 0.04462191 0.10292139]]
# array([0.86152769, 0.86681813, 0.10292139])

# %%
x = np.linspace(- np.pi/2,np.pi/2, 10000)
y = 1/(1+ np.exp(-x))
plt.plot(x, np.tan(x), '-')
plt.plot(x, y, '-')
plt.ylim(-1, 1)
# Out:
# (-1, 1)

# %%
print('hello')
print('hello')
# Out:
# hello
# hello

# %%
print('hello',end=' ')
print('hello',end=' ')
print('hello',end=' ')
# Out:
# hello hello hello
